# %%
#from skimage.measure import compare_ssim
import argparse
import imutils
import cv2

# 3. Load the two input images
imageA = cv2.imread('./Learning-to-See-in-the-Dark/result_Fuji/final' + '/10019_00_100_gt.png')
imageB = cv2.imread('./Learning-to-See-in-the-Dark/result_Fuji/final' + "/10019_00_100_out.png")

# 4. Convert the images to grayscale
grayA = cv2.cvtColor(imageA, cv2.COLOR_BGR2GRAY)
grayB = cv2.cvtColor(imageB, cv2.COLOR_BGR2GRAY)

# 5. Compute the Structural Similarity Index (SSIM) between the two
#    images, ensuring that the difference image is returned
(score, diff) = ssim(grayA, grayB, full=True)
diff = (diff * 255).astype("uint8")

# 6. You can print only the score if you want
print("SSIM: {}".format(score))


import math
import numpy as np

def calculate_psnr(img1, img2):
    # img1 and img2 have range [0, 255]
    img1 = img1.astype(np.float64)
    img2 = img2.astype(np.float64)
    mse = np.mean((img1 - img2)**2)
    if mse == 0:
        return float('inf')
    return 20 * math.log10(255.0 / math.sqrt(mse))

print("PSNR: {}".format(calculate_psnr(grayA,grayB)))
# Out:
# SSIM: 0.8851568370638887
# PSNR: 32.860521639212536

# %%
plt.imshow(imageA)

# %%
# 3. Load the two input images
imageA = cv2.imread('./Learning-to-See-in-the-Dark/iPhone/final' + '/livre_1_gt.png')
imageB = cv2.imread('./Learning-to-See-in-the-Dark/iPhone/final' + "/livre_1_out.png")
imageA = cv2.resize(imageA, dsize = (3024, 3024))
# 4. Convert the images to grayscale
grayA = cv2.cvtColor(imageA, cv2.COLOR_BGR2GRAY)
grayB = cv2.cvtColor(imageB, cv2.COLOR_BGR2GRAY)

# 5. Compute the Structural Similarity Index (SSIM) between the two
#    images, ensuring that the difference image is returned
(score, diff) = ssim(grayA, grayB, full=True)
diff = (diff * 255).astype("uint8")

# 6. You can print only the score if you want
print("SSIM: {}".format(score))


import math
import numpy as np

def calculate_psnr(img1, img2):
    # img1 and img2 have range [0, 255]
    img1 = img1.astype(np.float64)
    img2 = img2.astype(np.float64)
    mse = np.mean((img1 - img2)**2)
    if mse == 0:
        return float('inf')
    return 20 * math.log10(255.0 / math.sqrt(mse))

print("PSNR: {}".format(calculate_psnr(grayA,grayB)))
# Out:
# SSIM: 0.5332566951073113
# PSNR: 20.904899146069262

# %%
plt.imshow(imageA)
